# %% [markdown]
# # Query 4 – Fibre Optic Customers
#
# This query lists customers who use fibre optic internet service.

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from src.list_load import list_data_collect

churn_list = list_data_collect()

# %%
fibre_optic_customers = churn_list.loc[
    churn_list["InternetService"] == "Fiber optic",
    ["customerID", "InternetService"]
]

fibre_optic_customers
